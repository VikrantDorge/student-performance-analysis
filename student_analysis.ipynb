# %% [markdown]
# # Student Performance Analysis
#
# This notebook analyzes the student performance dataset.
# We perform data cleaning, analysis and visualization.

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("student/student-mat.csv", sep=";")
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
df.shape
# Out:
# (395, 33)

# %%
df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
avg_g3 = df['G3'].mean()
avg_g3
# Out:
# np.float64(10.415189873417722)

# %%
high_score_count = df[df['G3'] > 15].shape[0]
high_score_count
# Out:
# 40

# %%
df[['studytime', 'G3']].corr()
# Out:
#            studytime       G3
# studytime    1.00000  0.09782
# G3           0.09782  1.00000

# %%
import matplotlib.pyplot as plt

plt.hist(df['G3'])
plt.xlabel("Final Grade (G3)")
plt.ylabel("Number of Students")
plt.title("Distribution of Final Grades")
plt.show()

# %%
plt.scatter(df['studytime'], df['G3'])
plt.xlabel("Study Time")
plt.ylabel("Final Grade")
plt.title("Study Time vs Final Grade")
plt.show()

# %%
gender_avg = df.groupby('sex')['G3'].mean()
gender_avg
# Out:
# sex
# F     9.966346
# M    10.914439
# Name: G3, dtype: float64

# %%
gender_avg.plot(kind='bar')
plt.xlabel("Gender")
plt.ylabel("Average Final Grade")
plt.title("Average Grade by Gender")
plt.show()

# %% [markdown]
# ## Conclusion
#
# This project analyzed student performance using the student-mat dataset.
# Data cleaning was performed to handle missing values and duplicates.
# Average grades, study time impact, and gender-wise performance were analyzed.
# Visualizations helped in understanding student performance patterns.
